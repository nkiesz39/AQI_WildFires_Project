# %%
import requests
import pandas as pd
import plotly.express as px
from pandas import json_normalize

# %%
email = "shervorn.mathews@yahoo.com"
key = "russetbird18"
param = "88502,42102"
bdate = 20160101
edate = 20160701
state = "06"
url = f'https://aqs.epa.gov/data/api/dailyData/byState?email={email}&key={key}&param={param}&bdate={bdate}&edate={edate}&state={state}'

response = requests.get(url)

# %%
url
# Out:
# 'https://aqs.epa.gov/data/api/dailyData/byState?email=shervorn.mathews@yahoo.com&key=russetbird18&param=88502,42102,88101&bdate=20160101&edate=20160701&state=06'

# %%
data = response.json()

recs = data['Data']

starter_df = json_normalize(recs)

starter_df.head(10)
# Out:
#   state_code county_code site_number parameter_code  poc  latitude  longitude  \
# 0         06         011        1002          88502    3  39.18919 -121.99887
# 1         06         011        1002          88502    3  39.18919 -121.99887
# 2         06         011        1002          88502    3  39.18919 -121.99887
# 3         06         011        1002          88502    3  39.18919 -121.99887
# 4         06         011        1002          88502    3  39.18919 -121.99887
# 5         06         011        1002          88502    3  39.18919 -121.99887
# 6         06         011        1002          88502    3  39.18919 -121.99887
# 7         06         011        1002          88502    3  39.18919 -121.99887
# 8         06         011        1002          88502    3  39.18919 -121.99887
# 9         06         011        1002          88502    3  39.18919 -121.99887
#
#    datum                               parameter sample_duration_code  ...  \
# 0  NAD83  Acceptable PM2.5 AQI & Speciation Mass                    1  ...
# 1  NAD83  Acceptable PM2.5 AQI & Speciation Mass                    X  ...
# 2  NAD83  Acceptable PM2.5 AQI & Speciation Mass                    1  ...
# 3  NAD83  Acceptable PM2.5 AQI & Speciation Mass                    X  ...
# 4  NAD83  Acceptable PM2.5 AQI & Speciation Mass                    1  ...
# 5  NAD83  Acceptable PM2.5 AQI & Speciation Mass                    X  ...
# 6  NAD83  Acceptable PM2.5 AQI & Speciation Mass                    1  ...
# 7  NAD83  Acceptable PM2.5 AQI & Speciation Mass                    X  ...
# 8  NAD83  Acceptable PM2.5 AQI & Speciation Mass                    1  ...
# 9  NAD83  Acceptable PM2.5 AQI & Speciation Mass                    X  ...
#
#   method_code                                           method  \
# 0         731  Met-One BAM-1020 W/PM2.5 SCC - Beta Attenuation
# 1         731  Met-One BAM-1020 W/PM2.5 SCC - Beta Attenuation
# 2         731  Met-One BAM-1020 W/PM2.5 SCC - Beta Attenuation
# 3         731  Met-One BAM-1020 W/PM2.5 SCC - Beta Attenuation
# 4         731  Met-One BAM-1020 W/PM2.5 SCC - Beta Attenuation
# 5         731  Met-One BAM-1020 W/PM2.5 SCC - Beta Attenuation
# 6         731  Met-One BAM-1020 W/PM2.5 SCC - Beta Attenuation
# 7         731  Met-One BAM-1020 W/PM2.5 SCC - Beta Attenuation
# 8         731  Met-One BAM-1020 W/PM2.5 SCC - Beta Attenuation
# 9         731  Met-One BAM-1020 W/PM2.5 SCC - Beta Attenuation
#
#        local_site_name               site_address       state  county    city  \
# 0  Colusa-Sunrise Blvd  100 SUNRISE BLVD., COLUSA  California  Colusa  Colusa
# 1  Colusa-Sunrise Blvd  100 SUNRISE BLVD., COLUSA  California  Colusa  Colusa
# 2  Colusa-Sunrise Blvd  100 SUNRISE BLVD., COLUSA  California  Colusa  Colusa
# 3  Colusa-Sunrise Blvd  100 SUNRISE BLVD., COLUSA  California  Colusa  Colusa
# 4  Colusa-Sunrise Blvd  100 SUNRISE BLVD., COLUSA  California  Colusa  Colusa
# 5  Colusa-Sunrise Blvd  100 SUNRISE BLVD., COLUSA  California  Colusa  Colusa
# 6  Colusa-Sunrise Blvd  100 SUNRISE BLVD., COLUSA  California  Colusa  Colusa
# 7  Colusa-Sunrise Blvd  100 SUNRISE BLVD., COLUSA  California  Colusa  Colusa
# 8  Colusa-Sunrise Blvd  100 SUNRISE BLVD., COLUSA  California  Colusa  Colusa
# 9  Colusa-Sunrise Blvd  100 SUNRISE BLVD., COLUSA  California  Colusa  Colusa
#
#   cbsa_code  cbsa  date_of_last_change
# 0      None  None           2021-03-08
# 1      None  None           2023-02-05
# 2      None  None           2021-03-08
# 3      None  None           2023-02-05
# 4      None  None           2021-03-08
# 5      None  None           2023-02-05
# 6      None  None           2021-03-08
# 7      None  None           2023-02-05
# 8      None  None           2021-03-08
# 9      None  None           2023-02-05
#
# [10 rows x 32 columns]

# %%
starter_df.shape
# Out:
# (13609, 32)

# %%
list(starter_df.columns)
# Out:
# ['state_code',
#  'county_code',
#  'site_number',
#  'parameter_code',
#  'poc',
#  'latitude',
#  'longitude',
#  'datum',
#  'parameter',
#  'sample_duration_code',
#  'sample_duration',
#  'pollutant_standard',
#  'date_local',
#  'units_of_measure',
#  'event_type',
#  'observation_count',
#  'observation_percent',
#  'validity_indicator',
#  'arithmetic_mean',
#  'first_max_value',
#  'first_max_hour',
#  'aqi',
#  'method_code',
#  'method',
#  'local_site_name',
#  'site_address',
#  'state',
#  'county',
#  'city',
#  'cbsa_code',
#  'cbsa',
#  'date_of_last_change']

# %% [markdown]
# | State | Abbr | FIPS Code |
# | --- | ----------- | --- |
# | California | CA | 06 |
# | Paragraph | Text | Blah |

# %% [markdown]
# ## List of Columns
#
# ['state_code',
#  'county_code',
#  'site_number',
#  'parameter_code',
#  'poc',
#  'latitude',
#  'longitude',
#  'datum',
#  'parameter',
#  'sample_duration_code',
#  'sample_duration',
#  'pollutant_standard',
#  'date_local',
#  'units_of_measure',
#  'event_type',
#  'observation_count',
#  'observation_percent',
#  'validity_indicator',
#  'arithmetic_mean',
#  'first_max_value',
#  'first_max_hour',
#  'aqi',
#  'method_code',
#  'method',
#  'local_site_name',
#  'site_address',
#  'state',
#  'county',
#  'city',
#  'cbsa_code',
#  'cbsa',
#  'date_of_last_change']

# %%
df= starter_df

colToDrop = ['site_number', 'poc', 'datum', 'sample_duration_code', 'sample_duration', 'latitude',
             'longitude', 'state_code', 'county_code', 'parameter_code', 'method_code', 'method',
             'site_address', 'city', 'cbsa_code', 'cbsa', 'date_of_last_change', 'local_site_name',
             'pollutant_standard', 'event_type', 'first_max_hour', 'validity_indicator',
             'observation_percent', 'observation_count', 'arithmetic_mean']

df = df.drop(columns= colToDrop, axis = 1).convert_dtypes().drop_duplicates()

df = df.astype({"aqi": str})

df["date_local"] = pd.to_datetime(df["date_local"])

df = df[df.aqi != "<NA>"]

df = df.astype({"aqi": int})

df.head(10)
# Out:
#                                  parameter date_local  \
# 1   Acceptable PM2.5 AQI & Speciation Mass 2016-01-01
# 3   Acceptable PM2.5 AQI & Speciation Mass 2016-01-02
# 5   Acceptable PM2.5 AQI & Speciation Mass 2016-01-03
# 7   Acceptable PM2.5 AQI & Speciation Mass 2016-01-04
# 9   Acceptable PM2.5 AQI & Speciation Mass 2016-01-05
# 11  Acceptable PM2.5 AQI & Speciation Mass 2016-01-06
# 13  Acceptable PM2.5 AQI & Speciation Mass 2016-01-07
# 15  Acceptable PM2.5 AQI & Speciation Mass 2016-01-08
# 17  Acceptable PM2.5 AQI & Speciation Mass 2016-01-09
# 19  Acceptable PM2.5 AQI & Speciation Mass 2016-01-10
#
#                units_of_measure  first_max_value  aqi       state  county
# 1   Micrograms/cubic meter (LC)              3.6   15  California  Colusa
# 3   Micrograms/cubic meter (LC)              4.8   20  California  Colusa
# 5   Micrograms/cubic meter (LC)              9.0   38  California  Colusa
# 7   Micrograms/cubic meter (LC)             14.7   56  California  Colusa
# 9   Micrograms/cubic meter (LC)              7.0   29  California  Colusa
# 11  Micrograms/cubic meter (LC)              3.8   16  California  Colusa
# 13  Micrograms/cubic meter (LC)              7.3   30  California  Colusa
# 15  Micrograms/cubic meter (LC)              4.4   18  California  Colusa
# 17  Micrograms/cubic meter (LC)             12.3   51  California  Colusa
# 19  Micrograms/cubic meter (LC)              4.9   20  California  Colusa

# %%
df.dtypes
# Out:
# parameter                   string
# date_local          datetime64[ns]
# units_of_measure            string
# arithmetic_mean            Float64
# aqi                          int32
# state                       string
# county                      string
# dtype: object

# %%
df.shape
# Out:
# (24292, 7)

# %%
list(df.columns)
# Out:
# ['parameter',
#  'date_local',
#  'units_of_measure',
#  'arithmetic_mean',
#  'aqi',
#  'state',
#  'county']

# %%
df.parameter.unique()
# Out:
# <StringArray>
# ['PM2.5 - Local Conditions', 'Acceptable PM2.5 AQI & Speciation Mass']
# Length: 2, dtype: string

# %%
# Number of unique values in columns

print(df['aqi'].value_counts())
# Out:
# 20     674
# 18     656
# 23     653
# 28     646
# 13     639
#       ...
# 133      1
# 148      1
# 128      1
# 104      1
# 131      1
# Name: aqi, Length: 139, dtype: int64

# %%
list(df.columns)
# Out:
# ['parameter',
#  'date_local',
#  'units_of_measure',
#  'arithmetic_mean',
#  'aqi',
#  'state',
#  'county']

# %%
fig = px.line(df, x='date_local', y='aqi',
             color='county', 
            #  labels={
            #       "data_value": "Percent (%)",
            #       "yearstart": "Year"
            #   }, 
             title='Test Plot')
fig.show()
